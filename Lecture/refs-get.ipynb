// %% [markdown]
// # 讲义中的参考文献
//
// 使用 `getiref` 命令获取讲义中的参考文献列表：
//
// ```stata
// getiref {DOI}, m
// getiref {DOI}, m pdf
// getiref {DOI}, m bib
// ```

// %% [markdown]
// ## Heckman Selection Model

// %%
getiref
