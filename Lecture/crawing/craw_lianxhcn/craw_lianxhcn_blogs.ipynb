# %% [markdown]
# 1. 在浏览器中打开 <https://www.lianxh.cn/blogs/all.html>
# 2. 按 **F12** 打开开发者工具，选择 **Sources* 面板，然后点击左侧的文件图标

# %% [markdown]
# <img src="https://fig-lianxh.oss-cn-shenzhen.aliyuncs.com/20260312181836.png" width="700" alt="20260312181836">
