# %% [markdown]
# ## 爬取上交所公告：股票异常波动

# %% [markdown]
# ### 讨论提示词
#
# 我已经完成了讲义 'craw_01....md'
#
# 现在想写第二章 'craw_02_examples.md' ，包含三个例子，其中第二个例子是爬取上交所的公告
# - 页面：https://www.sse.com.cn/star/disclosure/listannouncement/
# - 检索关键词：'异常波动'
# - 特征：多页，包含 50 多个页面
#
# 学生特征：
# - 没有任何网页和爬虫基础，只学过 craw_01 讲义中的内容。
# - 我希望学生能以 https://www.sse.com.cn/star/disclosure/listannouncement/ 为起点，学会不断向 AI 提问，让学生根据 AI 的反馈和指导来了解网页结构，编写提示词，并生成 Python 代码。对于目前这个例子来讲，学生需要通过提问了解这个网页是动态的还是静态的，需要把哪些截图信息发给 AI ……
# - 注意：这个教学模式与传统的爬虫教程不同，在我倡导的模式下，即使零基础的学生，只要学会提问，就能在 AI 的帮助下不断学习，实现最终的爬取目标
#
# 你帮我规划一下，这个 Section  (‘## 2.2 爬取上交所「异常波动」公告’) 应该如何写？
