# %% [markdown]
# - 生成 Python 代码，用于执行 'create_synthetic_text.py'

# %%
# !python create_synthetic_text.py
# Out:
# ...
# 生成「金融文本分析」两章的全部文本素材
# ...
#
# [1/6] 生成借贷公告（50 条）...
#   → 已生成 50 条借贷公告 → data_raw\announcements/
#   → 变体分布:
#      standard_random: 13 条
#      float_rate: 7 条
#      html_noise: 5 条
#      fullwidth: 5 条
#      multi_loan: 5 条
#      incomplete: 4 条
#      exact_duplicate: 3 条
#      standard_seed: 1 条
#      wording_variant: 1 条
#      float_rate_seed: 1 条
#      html_fullwidth_seed: 1 条
#      term_month_seed: 1 条
#      incomplete_seed: 1 条
#      multi_loan_seed: 1 条
#      exact_duplicate_seed: 1 条
#
# [2/6] 生成财经新闻（6 条）...
#   → 已生成 6 条财经新闻 → data_raw\news/news_samples.csv
#
# [3/6] 生成央行货币政策执行报告片段（4 段）...
#   → 已生成 4 段央行报告 → data_raw\pboc_reports/
#
# [4/6] 生成年报 MD&A 片段（3 段）...
#   → 已生成 3 段年报 MD&A → data_raw\mda/
#
# [5/6] 生成交易所问询函片段（3 段）...
#   → 已生成 3 段问询函 → data_raw\inquiry_letters/
#
# [6/6] 生成分析师研报摘要（3 条）...
#   → 已生成 3 条研报摘要 → data_raw\analyst_reports/
#
# ...
# 全部素材生成完毕！
# 输出目录：d:\github_lianxh\dsfin\Lecture\text_analysis\codes\data_raw/
# ...
#
# 文件统计：
# data_raw/
#   analyst_reports/
# ...
